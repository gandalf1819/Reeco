# %%
import requests
import boto3
import json

API_KEY="0MEKSff1SKt-5wsVgljGLljx-o_V8M8TtPQ9GpZIFmiXA3ZC9iFD9_4usUZ0JXsJcQYLPfKrwgNbFQ_ied69DtQwaA9Y_FD_yjZ8tzBwerJola1n9-4zI3Ik1PmTXXYx"

# %%
# API specifications

API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  
location = ['Brooklyn','Bronx']
term = "restaurants"
headers = {'Authorization': 'Bearer %s' % API_KEY}

# %%
# GET request to Yelp API to retrieve data for params
def suggest(location,off):
	params={"term":term, "location":"Manhattan", "limit":50, "offset":off, "categories":"Indian,American"}
	return requests.get(API_HOST+SEARCH_PATH,params=params,headers=headers).json()

suggestions = suggest(location,50)
print(suggestions)
# Out:
# {'businesses': [{'id': 'ogCC-lJJYnwXDvKGmKZ6Sw', 'alias': 'woorijip-new-york-2', 'name': 'Woorijip', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NZcGFutBjf1frDkslh6urw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/woorijip-new-york-2?adjust_creative=PiFA6AQtKySkn0xlYipNcw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PiFA6AQtKySkn0xlYipNcw', 'review_count': 2579, 'categories': [{'alias': 'korean', 'title': 'Korean'}], 'rating': 4.0, 'coordinates': {'latitude': 40.74747, 'longitude': -73.98648}, 'transactions': [], 'price': '$', 'location': {'address1': '12 W 32nd St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10001', 'country': 'US', 'state': 'NY', 'display_address': ['12 W 32nd St', 'New York, NY 10001']}, 'phone': '+12122441115', 'display_phone': '(212) 244-1115', 'distance': 1578.239664148041}, {'id': 'VLGmFHE4s0Sfu0piMVQa1Q', 'alias': 'hold-fast-kitchen-and-spirits-new-york', 'name': 'Hold Fast Kitchen and Spirits', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2a8BP3w4_pgEn8Y0E6TBow/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/hold-fast-kitchen-and-spirits-new-york?adjust_creative=PiFA6AQtKySkn0xlYipNcw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PiFA6AQtKySkn0xlYipNcw', 'review_count': 238, 'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}], 'rating': 5.0, 'coordinates': {'latitude': 40.76064, 'longitude': -73.99023}, 'transactions': [], 'price': '$$', 'location': {'address1': '364 W 46th St', 'address2': None, 'address3': '', 'city': 'New York', 'zip_code': '10036', 'country': 'US', 'state': 'NY', 'display_address': ['364 W 46th St', 'New York, NY 10036']}, 'phone': '+19172616691', 'display_phone': '(917) 261-6691', 'distance': 991.6684952173948}, {'id': 'hdiuRS9sVZSMReZm4oV5SA', 'alias': 'da-andrea-new-york', 'name': 'Da Andrea', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IesapW_Zj-Mp-1KdLbAw9Q/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/da-andrea-new-york?adjust_creative=PiFA6AQtKySkn0xlYipNcw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PiFA6AQtKySkn0xlYipNcw', 'review_count': 725, 'categories': [{'alias': 'tuscan', 'title': 'Tuscan'}], 'rating': 4.0, 'coordinates': {'latitude': 40.736218, 'longitude': -73.99597}, 'transactions': ['delivery', 'restaurant_reservation', 'pickup'], 'price': '$$', 'location': {'address1': '35 W 13th St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10011', 'country': 'US', 'state': 'NY', 'display_address': ['35 W 13th St', 'New York, NY 10011']}, 'phone': '+12123671979', 'display_phone': '(212) 367-1979', 'distance': 3047.2448524235715}, {'id': '-OixbLnFLCzQclxCSbUQ8w', 'alias': 'up-thai-new-york', 'name': 'Up Thai', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/g9J3naudQZY72qJAHUOI8A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/up-thai-new-york?adjust_creative=PiFA6AQtKySkn0xlYipNcw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PiFA6AQtKySkn0xlYipNcw', 'review_count': 2126, 'categories': [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}], 'rating': 4.5, 'coordinates': {'latitude': 40.7698275926665, 'longitude': -73.9576330868512}, 'transactions': ['delivery', 'pickup'], 'price': '$$', 'location': {'address1': '1411 2nd Ave', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10021', 'country': 'US', 'state': 'NY', 'display_address': ['1411 2nd Ave', 'New York, NY 10021']}, 'phone': '+12122561188', 'display_phone': '(212) 256-1188', 'distance': 2056.9347338849025}, {'id': 'V7lXZKBDzScDeGB8JmnzSA', 'alias': 'katzs-delicatessen-new-york', 'name': "Katz's Delicatessen", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B6xNx79cSE7bFxqERBYOhg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/katzs-delicatessen-n ...

# %%
# Dump list to json
with open("cuisines-yelp.json", "w") as cuisines:
 	json.dump(suggestions, cuisines, indent=4,sort_keys=4)

# %% [markdown]
# #### TODO: Iterate through locations list
# #### TODO: Iterate through cuisines
